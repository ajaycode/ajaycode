# %% [markdown]
# # Pandas Tutorial

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('people-example.csv')

# %%
df
# Out:
#    First Name    Last Name        Country  age
# 0         Bob        Smith  United States   24
# 1       Alice     Williams         Canada   23
# 2     Malcolm         Jone        England   22
# 3       Felix        Brown            USA   23
# 4        Alex       Cooper         Poland   23
# 5         Tod     Campbell  United States   22
# 6       Derek         Ward    Switzerland   25
# 7    Narendra       "Modi"        "India"   55
# 8         Ian      "Khama"     "Botswana"   43
# 9      Idriss       "Deby"         "Chad"   39
# 10   Francois   "Hollande"       "France"   59
# 11     Daniel     "Ortega"    "Nicaragua"   61
#    First Name    Last Name        Country  age
# 0         Bob        Smith  United States   24
# 1       Alice     Williams         Canada   23
# 2     Malcolm         Jone        England   22
# 3       Felix        Brown            USA   23
# 4        Alex       Cooper         Poland   23
# 5         Tod     Campbell  United States   22
# 6       Derek         Ward    Switzerland   25
# 7    Narendra       "Modi"        "India"   55
# 8         Ian      "Khama"     "Botswana"   43
# 9      Idriss       "Deby"         "Chad"   39
# 10   Francois   "Hollande"       "France"   59
# 11     Daniel     "Ortega"    "Nicaragua"   61

# %%
df['age'] > 23
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: age, dtype: bool
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# Name: age, dtype: bool

# %%
df [df['age'] <=23]
# Out:
#   First Name Last Name        Country  age
# 1      Alice  Williams         Canada   23
# 2    Malcolm      Jone        England   22
# 3      Felix     Brown            USA   23
# 4       Alex    Cooper         Poland   23
# 5        Tod  Campbell  United States   22
#   First Name Last Name        Country  age
# 1      Alice  Williams         Canada   23
# 2    Malcolm      Jone        England   22
# 3      Felix     Brown            USA   23
# 4       Alex    Cooper         Poland   23
# 5        Tod  Campbell  United States   22

# %%
df[df['Country']=='USA']
# Out:
#   First Name Last Name Country  age
# 3      Felix     Brown     USA   23
#   First Name Last Name Country  age
# 3      Felix     Brown     USA   23

# %%
person = {'First Name': 'Joe', 'Last Name': 'Williams', 'Country':'Canada', 
         'age': 19}
person
# Out:
# {'Country': 'Canada', 'First Name': 'Joe', 'Last Name': 'Williams', 'age': 19}
# {'Country': 'Canada', 'First Name': 'Joe', 'Last Name': 'Williams', 'age': 19}

# %%
df.size
# Out:
# 48
# 48

# %%
df
# Out:
#    First Name    Last Name        Country  age
# 0         Bob        Smith  United States   24
# 1       Alice     Williams         Canada   23
# 2     Malcolm         Jone        England   22
# 3       Felix        Brown            USA   23
# 4        Alex       Cooper         Poland   23
# 5         Tod     Campbell  United States   22
# 6       Derek         Ward    Switzerland   25
# 7    Narendra       "Modi"        "India"   55
# 8         Ian      "Khama"     "Botswana"   43
# 9      Idriss       "Deby"         "Chad"   39
# 10   Francois   "Hollande"       "France"   59
# 11     Daniel     "Ortega"    "Nicaragua"   61
#    First Name    Last Name        Country  age
# 0         Bob        Smith  United States   24
# 1       Alice     Williams         Canada   23
# 2     Malcolm         Jone        England   22
# 3       Felix        Brown            USA   23
# 4        Alex       Cooper         Poland   23
# 5         Tod     Campbell  United States   22
# 6       Derek         Ward    Switzerland   25
# 7    Narendra       "Modi"        "India"   55
# 8         Ian      "Khama"     "Botswana"   43
# 9      Idriss       "Deby"         "Chad"   39
# 10   Francois   "Hollande"       "France"   59
# 11     Daniel     "Ortega"    "Nicaragua"   61

# %%
df.loc[5]
# Out:
# First Name              Tod
# Last Name          Campbell
# Country       United States
# age                      22
# Name: 5, dtype: object
# First Name              Tod
# Last Name          Campbell
# Country       United States
# age                      22
# Name: 5, dtype: object

# %%
df.loc[6]
# Out:
# First Name          Derek
# Last Name            Ward
# Country       Switzerland
# age                    25
# Name: 6, dtype: object
# First Name          Derek
# Last Name            Ward
# Country       Switzerland
# age                    25
# Name: 6, dtype: object

# %%
#df.loc[7]=person

# %%
person
# Out:
# {'Country': 'Canada', 'First Name': 'Joe', 'Last Name': 'Williams', 'age': 19}
# {'Country': 'Canada', 'First Name': 'Joe', 'Last Name': 'Williams', 'age': 19}

# %%
df
# Out:
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8         Ian      "Khama"     "Botswana"          43
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8         Ian      "Khama"     "Botswana"          43
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61

# %%
df[df['Last Name']=='Williams']
# Out:
#   First Name Last Name Country age
# 1      Alice  Williams  Canada  23
#   First Name Last Name Country age
# 1      Alice  Williams  Canada  23

# %%
df2 = df.copy()
df2
# Out:
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8         Ian      "Khama"     "Botswana"          43
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8         Ian      "Khama"     "Botswana"          43
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61

# %%
person
# Out:
# {'Country': 'Canada', 'First Name': 'Joe', 'Last Name': 'Williams', 'age': 19}
# {'Country': 'Canada', 'First Name': 'Joe', 'Last Name': 'Williams', 'age': 19}

# %%
person2 = {'Country': 'France', 'First Name': 'Nikolas', 'Last Name': 'Sarkozi', 'age': 55}

# %%
df2.loc[8]=person2

# %%
df2
# Out:
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8     Nikolas      Sarkozi         France          55
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8     Nikolas      Sarkozi         France          55
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61

# %%
df
# Out:
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8         Ian      "Khama"     "Botswana"          43
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61
#    First Name    Last Name        Country         age
# 0         Bob        Smith  United States          24
# 1       Alice     Williams         Canada          23
# 2     Malcolm         Jone        England          22
# 3       Felix        Brown            USA          23
# 4        Alex       Cooper         Poland          23
# 5         Tod     Campbell  United States          22
# 6       Derek         Ward    Switzerland          25
# 7     Country    Last Name            age  First Name
# 8         Ian      "Khama"     "Botswana"          43
# 9      Idriss       "Deby"         "Chad"          39
# 10   Francois   "Hollande"       "France"          59
# 11     Daniel     "Ortega"    "Nicaragua"          61

# %%
df = df[df['age'] != 'First Name']
df.index
# Out:
# Int64Index([0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11], dtype='int64')
# Int64Index([0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11], dtype='int64')

# %%
df
# Out:
#    First Name    Last Name        Country age
# 0         Bob        Smith  United States  24
# 1       Alice     Williams         Canada  23
# 2     Malcolm         Jone        England  22
# 3       Felix        Brown            USA  23
# 4        Alex       Cooper         Poland  23
# 5         Tod     Campbell  United States  22
# 6       Derek         Ward    Switzerland  25
# 8         Ian      "Khama"     "Botswana"  43
# 9      Idriss       "Deby"         "Chad"  39
# 10   Francois   "Hollande"       "France"  59
# 11     Daniel     "Ortega"    "Nicaragua"  61
#    First Name    Last Name        Country age
# 0         Bob        Smith  United States  24
# 1       Alice     Williams         Canada  23
# 2     Malcolm         Jone        England  22
# 3       Felix        Brown            USA  23
# 4        Alex       Cooper         Poland  23
# 5         Tod     Campbell  United States  22
# 6       Derek         Ward    Switzerland  25
# 8         Ian      "Khama"     "Botswana"  43
# 9      Idriss       "Deby"         "Chad"  39
# 10   Francois   "Hollande"       "France"  59
# 11     Daniel     "Ortega"    "Nicaragua"  61

# %%
df.columns
# Out:
# Index(['First Name', 'Last Name', 'Country', 'age'], dtype='object')
# Index(['First Name', 'Last Name', 'Country', 'age'], dtype='object')

# %%
df.values
# Out:
# array([['Bob', 'Smith', 'United States', 24],
#        ['Alice', 'Williams', 'Canada', 23],
#        ['Malcolm', 'Jone', 'England', 22],
#        ['Felix', 'Brown', 'USA', 23],
#        ['Alex', 'Cooper', 'Poland', 23],
#        ['Tod', 'Campbell', 'United States', 22],
#        ['Derek', 'Ward', 'Switzerland', 25],
#        ['Ian', ' "Khama"', ' "Botswana"', 43],
#        ['Idriss', ' "Deby"', ' "Chad"', 39],
#        ['Francois', ' "Hollande"', ' "France"', 59],
#        ['Daniel', ' "Ortega"', ' "Nicaragua"', 61]], dtype=object)
# array([['Bob', 'Smith', 'United States', 24],
#        ['Alice', 'Williams', 'Canada', 23],
#        ['Malcolm', 'Jone', 'England', 22],
#        ['Felix', 'Brown', 'USA', 23],
#        ['Alex', 'Cooper', 'Poland', 23],
#        ['Tod', 'Campbell', 'United States', 22],
#        ['Derek', 'Ward', 'Switzerland', 25],
#        ['Ian', ' "Khama"', ' "Botswana"', 43],
#        ['Idriss', ' "Deby"', ' "Chad"', 39],
#        ['Francois', ' "Hollande"', ' "France"', 59],
#        ['Daniel', ' "Ortega"', ' "Nicaragua"', 61]], dtype=object)

# %%
df.sort(columns='age')
# Out:
#    First Name    Last Name        Country age
# 2     Malcolm         Jone        England  22
# 5         Tod     Campbell  United States  22
# 3       Felix        Brown            USA  23
# 4        Alex       Cooper         Poland  23
# 1       Alice     Williams         Canada  23
# 0         Bob        Smith  United States  24
# 6       Derek         Ward    Switzerland  25
# 9      Idriss       "Deby"         "Chad"  39
# 8         Ian      "Khama"     "Botswana"  43
# 10   Francois   "Hollande"       "France"  59
# 11     Daniel     "Ortega"    "Nicaragua"  61
#    First Name    Last Name        Country age
# 2     Malcolm         Jone        England  22
# 5         Tod     Campbell  United States  22
# 3       Felix        Brown            USA  23
# 4        Alex       Cooper         Poland  23
# 1       Alice     Williams         Canada  23
# 0         Bob        Smith  United States  24
# 6       Derek         Ward    Switzerland  25
# 9      Idriss       "Deby"         "Chad"  39
# 8         Ian      "Khama"     "Botswana"  43
# 10   Francois   "Hollande"       "France"  59
# 11     Daniel     "Ortega"    "Nicaragua"  61

# %%
df.T
# Out:
#                        0         1        2      3       4              5   \
# First Name            Bob     Alice  Malcolm  Felix    Alex            Tod
# Last Name           Smith  Williams     Jone  Brown  Cooper       Campbell
# Country     United States    Canada  England    USA  Poland  United States
# age                    24        23       22     23      23             22
#
#                      6            8        9            10            11
# First Name        Derek          Ian   Idriss     Francois        Daniel
# Last Name          Ward      "Khama"   "Deby"   "Hollande"      "Ortega"
# Country     Switzerland   "Botswana"   "Chad"     "France"   "Nicaragua"
# age                  25           43       39           59            61
#                        0         1        2      3       4              5   \
# First Name            Bob     Alice  Malcolm  Felix    Alex            Tod
# Last Name           Smith  Williams     Jone  Brown  Cooper       Campbell
# Country     United States    Canada  England    USA  Poland  United States
# age                    24        23       22     23      23             22
#
#                      6            8        9            10            11
# First Name        Derek          Ian   Idriss     Francois        Daniel
# Last Name          Ward      "Khama"   "Deby"   "Hollande"      "Ortega"
# Country     Switzerland   "Botswana"   "Chad"     "France"   "Nicaragua"
# age                  25           43       39           59            61

# %%
df.age
# Out:
# 0     24
# 1     23
# 2     22
# 3     23
# 4     23
# 5     22
# 6     25
# 8     43
# 9     39
# 10    59
# 11    61
# Name: age, dtype: object
# 0     24
# 1     23
# 2     22
# 3     23
# 4     23
# 5     22
# 6     25
# 8     43
# 9     39
# 10    59
# 11    61
# Name: age, dtype: object

# %%
df['age']
# Out:
# 0     24
# 1     23
# 2     22
# 3     23
# 4     23
# 5     22
# 6     25
# 8     43
# 9     39
# 10    59
# 11    61
# Name: age, dtype: object
# 0     24
# 1     23
# 2     22
# 3     23
# 4     23
# 5     22
# 6     25
# 8     43
# 9     39
# 10    59
# 11    61
# Name: age, dtype: object

# %%
df.mean()
# Out:
# Series([], dtype: float64)
# Series([], dtype: float64)

# %%
df.median()
# Out:
# Series([], dtype: float64)
# Series([], dtype: float64)

# %%
df
# Out:
#    First Name    Last Name        Country age
# 0         Bob        Smith  United States  24
# 1       Alice     Williams         Canada  23
# 2     Malcolm         Jone        England  22
# 3       Felix        Brown            USA  23
# 4        Alex       Cooper         Poland  23
# 5         Tod     Campbell  United States  22
# 6       Derek         Ward    Switzerland  25
# 8         Ian      "Khama"     "Botswana"  43
# 9      Idriss       "Deby"         "Chad"  39
# 10   Francois   "Hollande"       "France"  59
# 11     Daniel     "Ortega"    "Nicaragua"  61
#    First Name    Last Name        Country age
# 0         Bob        Smith  United States  24
# 1       Alice     Williams         Canada  23
# 2     Malcolm         Jone        England  22
# 3       Felix        Brown            USA  23
# 4        Alex       Cooper         Poland  23
# 5         Tod     Campbell  United States  22
# 6       Derek         Ward    Switzerland  25
# 8         Ian      "Khama"     "Botswana"  43
# 9      Idriss       "Deby"         "Chad"  39
# 10   Francois   "Hollande"       "France"  59
# 11     Daniel     "Ortega"    "Nicaragua"  61

# %%
df[(df['Last Name'] == 'Williams') & (df['age']< 20)]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, Country, age]
# Index: []
# Empty DataFrame
# Columns: [First Name, Last Name, Country, age]
# Index: []

# %%
df[(df['Last Name'] == 'Williams') & (df['age']< 24)]
# Out:
#   First Name Last Name Country age
# 1      Alice  Williams  Canada  23
#   First Name Last Name Country age
# 1      Alice  Williams  Canada  23

# %%
df[['Last Name', 'First Name']]
# Out:
#       Last Name First Name
# 0         Smith        Bob
# 1      Williams      Alice
# 2          Jone    Malcolm
# 3         Brown      Felix
# 4        Cooper       Alex
# 5      Campbell        Tod
# 6          Ward      Derek
# 8       "Khama"        Ian
# 9        "Deby"     Idriss
# 10   "Hollande"   Francois
# 11     "Ortega"     Daniel
#       Last Name First Name
# 0         Smith        Bob
# 1      Williams      Alice
# 2          Jone    Malcolm
# 3         Brown      Felix
# 4        Cooper       Alex
# 5      Campbell        Tod
# 6          Ward      Derek
# 8       "Khama"        Ian
# 9        "Deby"     Idriss
# 10   "Hollande"   Francois
# 11     "Ortega"     Daniel

# %%
df['age_squared'] =df['age']*df['age']
df
# Out:
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    First Name    Last Name        Country age age_squared
# 0         Bob        Smith  United States  24         576
# 1       Alice     Williams         Canada  23         529
# 2     Malcolm         Jone        England  22         484
# 3       Felix        Brown            USA  23         529
# 4        Alex       Cooper         Poland  23         529
# 5         Tod     Campbell  United States  22         484
# 6       Derek         Ward    Switzerland  25         625
# 8         Ian      "Khama"     "Botswana"  43        1849
# 9      Idriss       "Deby"         "Chad"  39        1521
# 10   Francois   "Hollande"       "France"  59        3481
# 11     Daniel     "Ortega"    "Nicaragua"  61        3721
#    First Name    Last Name        Country age age_squared
# 0         Bob        Smith  United States  24         576
# 1       Alice     Williams         Canada  23         529
# 2     Malcolm         Jone        England  22         484
# 3       Felix        Brown            USA  23         529
# 4        Alex       Cooper         Poland  23         529
# 5         Tod     Campbell  United States  22         484
# 6       Derek         Ward    Switzerland  25         625
# 8         Ian      "Khama"     "Botswana"  43        1849
# 9      Idriss       "Deby"         "Chad"  39        1521
# 10   Francois   "Hollande"       "France"  59        3481
# 11     Daniel     "Ortega"    "Nicaragua"  61        3721

# %%
df.groupby('age').sum()
# Out:
#          First Name            Last Name               Country  age_squared
# age
# 22       MalcolmTod         JoneCampbell  EnglandUnited States          968
# 23   AliceFelixAlex  WilliamsBrownCooper       CanadaUSAPoland         1587
# 24              Bob                Smith         United States          576
# 25            Derek                 Ward           Switzerland          625
# 39           Idriss               "Deby"                "Chad"         1521
# 43              Ian              "Khama"            "Botswana"         1849
# 59         Francois           "Hollande"              "France"         3481
# 61           Daniel             "Ortega"           "Nicaragua"         3721
#          First Name            Last Name               Country  age_squared
# age
# 22       MalcolmTod         JoneCampbell  EnglandUnited States          968
# 23   AliceFelixAlex  WilliamsBrownCooper       CanadaUSAPoland         1587
# 24              Bob                Smith         United States          576
# 25            Derek                 Ward           Switzerland          625
# 39           Idriss               "Deby"                "Chad"         1521
# 43              Ian              "Khama"            "Botswana"         1849
# 59         Francois           "Hollande"              "France"         3481
# 61           Daniel             "Ortega"           "Nicaragua"         3721

# %%
df.groupby('age').count()
# Out:
#      First Name  Last Name  Country  age_squared
# age
# 22            2          2        2            2
# 23            3          3        3            3
# 24            1          1        1            1
# 25            1          1        1            1
# 39            1          1        1            1
# 43            1          1        1            1
# 59            1          1        1            1
# 61            1          1        1            1
#      First Name  Last Name  Country  age_squared
# age
# 22            2          2        2            2
# 23            3          3        3            3
# 24            1          1        1            1
# 25            1          1        1            1
# 39            1          1        1            1
# 43            1          1        1            1
# 59            1          1        1            1
# 61            1          1        1            1

# %%
pd.pivot_table(df, values='age', index='Country', columns='age_squared')
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-79-e4ce20a638b6> in <module>()
# ----> 1 pd.pivot_table(df, values='age', index='Country', columns='age_squared')
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna)
#     109
#     110     grouped = data.groupby(keys)
# --> 111     agged = grouped.agg(aggfunc)
#     112
#     113     table = agged
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in agg(self, func, *args, **kwargs)
#     683     @Appender(_agg_doc)
#     684     def agg(self, func, *args, **kwargs):
# --> 685         return self.aggregate(func, *args, **kwargs)
#     686
#     687     def _iterate_slices(self):
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    2635     def aggregate(self, arg, *args, **kwargs):
#    2636         if isinstance(arg, compat.string_types):
# -> 2637             return getattr(self, arg)(*args, **kwargs)
#    2638
#    2639         result = OrderedDict()
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in mean(self)
#     698         """
#     699         try:
# --> 700             return self._cython_agg_general('mean')
#     701         except GroupByError:
#     702             raise
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, numeric_only)
#    2558
#    2559     def _cython_agg_general(self, how, numeric_only=True):
# -> 2560         new_items, new_blocks = self._cython_agg_blocks(how, numeric_only=numeric_only)
#    2561         return self._wrap_agged_blocks(new_items, new_blocks)
#    2562
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_blocks(self, how, numeric_only)
#    2605
#    2606         if len(new_blocks) == 0:
# -> 2607             raise DataError('No numeric types to aggregate')
#    2608
#    2609         return data.items, new_blocks
#
# DataError: No numeric types to aggregate
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-79-e4ce20a638b6> in <module>()
# ----> 1 pd.pivot_table(df, values='age', index='Country', columns='age_squared')
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\tools\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna)
#     109
#     110     grouped = data.groupby(keys)
# --> 111     agged = grouped.agg(aggfunc)
#     112
#     113     table = agged
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in agg(self, func, *args, **kwargs)
#     683     @Appender(_agg_doc)
#     684     def agg(self, func, *args, **kwargs):
# --> 685         return self.aggregate(func, *args, **kwargs)
#     686
#     687     def _iterate_slices(self):
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    2635     def aggregate(self, arg, *args, **kwargs):
#    2636         if isinstance(arg, compat.string_types):
# -> 2637             return getattr(self, arg)(*args, **kwargs)
#    2638
#    2639         result = OrderedDict()
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in mean(self)
#     698         """
#     699         try:
# --> 700             return self._cython_agg_general('mean')
#     701         except GroupByError:
#     702             raise
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_general(self, how, numeric_only)
#    2558
#    2559     def _cython_agg_general(self, how, numeric_only=True):
# -> 2560         new_items, new_blocks = self._cython_agg_blocks(how, numeric_only=numeric_only)
#    2561         return self._wrap_agged_blocks(new_items, new_blocks)
#    2562
#
# C:\Users\agummadi\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\groupby.py in _cython_agg_blocks(self, how, numeric_only)
#    2605
#    2606         if len(new_blocks) == 0:
# -> 2607             raise DataError('No numeric types to aggregate')
#    2608
#    2609         return data.items, new_blocks
#
# DataError: No numeric types to aggregate

# %%
df.describe()
# Out:
#        First Name Last Name        Country  age  age_squared
# count          11        11             11   11           11
# unique         11        11             10    8            8
# top         Felix  Campbell  United States   23          529
# freq            1         1              2    3            3
#        First Name Last Name        Country  age  age_squared
# count          11        11             11   11           11
# unique         11        11             10    8            8
# top         Felix  Campbell  United States   23          529
# freq            1         1              2    3            3

# %%
#Covariance between suitable columns
df.cov()

# %%
#correlation
df.corr()

# %%
df.sort (columns='age')

# %%
df.sort(columns=['age', 'Country'], ascending='True')

# %%
df.sort(columns=[ 'Country','age'], ascending='True')

# %%
df.loc[6, ['First Name']]

# %%
df.iloc[6]

# %%
df.iloc[1:3]

# %%
df.groupby('Country').sum()

# %%
df.groupby(['Country', 'First Name']).sum()
# Out:
#                             Last Name         age
# Country       First Name
#  "Botswana"   Ian             "Khama"          43
#  "Chad"       Idriss           "Deby"          39
#  "France"     Francois     "Hollande"          59
#  "Nicaragua"  Daniel         "Ortega"          61
# Canada        Alice          Williams          23
# England       Malcolm            Jone          22
# Poland        Alex             Cooper          23
# Switzerland   Derek              Ward          25
# USA           Felix             Brown          23
# United States Bob               Smith          24
#               Tod            Campbell          22
# age           Country       Last Name  First Name
#                             Last Name         age
# Country       First Name
#  "Botswana"   Ian             "Khama"          43
#  "Chad"       Idriss           "Deby"          39
#  "France"     Francois     "Hollande"          59
#  "Nicaragua"  Daniel         "Ortega"          61
# Canada        Alice          Williams          23
# England       Malcolm            Jone          22
# Poland        Alex             Cooper          23
# Switzerland   Derek              Ward          25
# USA           Felix             Brown          23
# United States Bob               Smith          24
#               Tod            Campbell          22
# age           Country       Last Name  First Name

# %%
# %matplotlib inline
my_plot = df['age'].plot(kind='bar',  title="First Sample Chart")
my_plot.set_xlabel('Country')
my_plot.set_ylabel('Age (years)')

# %%
#Add the names for the x axis
#Change the index to the First and Last Names, so that the names show up along the x axis
indexed_df=df.set_index(['First Name', 'Last Name'])

# %%
indexed_df.index
# Out:
# MultiIndex(levels=[['Alex', 'Alice', 'Bob', 'Daniel', 'Derek', 'Felix', 'Francois', 'Ian', 'Idriss', 'Malcolm', 'Tod'], [' "Deby"', ' "Hollande"', ' "Khama"', ' "Ortega"', 'Brown', 'Campbell', 'Cooper', 'Jone', 'Smith', 'Ward', 'Williams']],
#            labels=[[2, 1, 9, 5, 0, 10, 4, 7, 8, 6, 3], [8, 10, 7, 4, 6, 5, 9, 2, 0, 1, 3]],
#            names=['First Name', 'Last Name'])
# MultiIndex(levels=[['Alex', 'Alice', 'Bob', 'Daniel', 'Derek', 'Felix', 'Francois', 'Ian', 'Idriss', 'Malcolm', 'Tod'], [' "Deby"', ' "Hollande"', ' "Khama"', ' "Ortega"', 'Brown', 'Campbell', 'Cooper', 'Jone', 'Smith', 'Ward', 'Williams']],
#            labels=[[2, 1, 9, 5, 0, 10, 4, 7, 8, 6, 3], [8, 10, 7, 4, 6, 5, 9, 2, 0, 1, 3]],
#            names=['First Name', 'Last Name'])

# %%
# %matplotlib inline
pd.options.display.mpl_style = 'default'
my_plot = indexed_df['age'].plot(kind='bar',  title="First Sample Chart")
my_plot.set_xlabel('Country')
my_plot.set_ylabel('Age (years)')
picture = my_plot.get_figure()
picture.savefig("20160105-sample-chart.png") #Dumps the graph into a file
